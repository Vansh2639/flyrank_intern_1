# %% [markdown]
# <a href="https://colab.research.google.com/github/Vansh2639/flyrank_intern_1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Vansh2639/flyrank_intern_1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# I chose Lane 2: Refresh / Content Opportunity Scoring because it focuses on a
# practical business problem of helping SEO teams decide which webpages should
# be reviewed first for refresh, expansion, protection, pruning, or monitoring.
# Instead of manually reviewing thousands of pages, this project aims to build
# a ranked recommendation system that prioritizes pages using observable signals
# such as impressions, CTR, content age, and update history. I selected this
# lane because it builds directly on the starter notebooks, aligns with the
# internship workflow, and allows me to compare transparent rule-based methods
# with machine learning while keeping the recommendations explainable through
# confidence scores and reason codes.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This project improves the decision of which webpages should be reviewed first
# for refresh, expansion, protection, pruning, or monitoring. The output will
# be used by SEO managers or content editors to prioritize their work and focus
# on the pages that are most likely to benefit from review. A wrong recommendation
# could waste time and resources by sending editors to pages that do not need
# attention, or it could miss genuinely declining pages, allowing them to lose
# traffic and search visibility. Therefore, the model is intended to support
# human decision-making rather than replace it.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import sys
import subprocess
import pandas as pd

REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Total Pages: {len(df)}")
print(f"Total Clients: {df['client_id'].nunique()}")

corr = df["search_volume"].corr(df["impressions_90d"])
print(f"Correlation between Search Volume and Impressions: {corr:.3f}")
# Out:
# Total Pages: 30000
# Total Clients: 32
# Correlation between Search Volume and Impressions: 0.001

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This project will identify observed patterns in historical search performance
# data and provide a ranked list of webpages that may deserve review. The
# recommendations are intended to support SEO teams in making better decisions
# by highlighting pages that appear to be stronger candidates for refresh or
# monitoring. This work cannot prove that refreshing a page will improve its
# rankings or traffic, nor can it predict Google's ranking algorithm. Any
# findings will be treated as observed relationships and decision-support
# insights rather than causal proof.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
